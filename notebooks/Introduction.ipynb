# %%
from cmip6_preprocessing.preprocessing import full_preprocessing

# %%
# open ESMCol catalog
import intake
col = intake.open_esm_datastore("../../cmip6hack-ocean-bgc/catalogs/pangeo-cmip6.json")

# %%
# search and display data
cat = col.search(experiment_id=['piControl'],variable_id=['uo', 'vo', 'thetao'],
                 grid_label='gn')
cat.df
# Out:
#       activity_id institution_id      source_id experiment_id member_id  \
# 221          CMIP            AWI  AWI-CM-1-1-MR     piControl  r1i1p1f1
# 222          CMIP            AWI  AWI-CM-1-1-MR     piControl  r1i1p1f1
# 223          CMIP            AWI  AWI-CM-1-1-MR     piControl  r1i1p1f1
# 496          CMIP            BCC    BCC-CSM2-MR     piControl  r1i1p1f1
# 498          CMIP            BCC    BCC-CSM2-MR     piControl  r1i1p1f1
# ...           ...            ...            ...           ...       ...
# 17166        CMIP            SNU    SAM0-UNICON     piControl  r1i1p1f1
# 17168        CMIP            SNU    SAM0-UNICON     piControl  r1i1p1f1
# 17239        CMIP             UA     MCM-UA-1-0     piControl  r1i1p1f1
# 17240        CMIP             UA     MCM-UA-1-0     piControl  r1i1p1f1
# 17241        CMIP             UA     MCM-UA-1-0     piControl  r1i1p1f1
#
#       table_id variable_id grid_label  \
# 221       Omon      thetao         gn
# 222       Omon          uo         gn
# 223       Omon          vo         gn
# 496       Omon      thetao         gn
# 498       Omon          uo         gn
# ...        ...         ...        ...
# 17166     Omon          uo         gn
# 17168     Omon          vo         gn
# 17239     Omon      thetao         gn
# 17240     Omon          uo         gn
# 17241     Omon          vo         gn
#
#                                                   zstore  dcpp_init_year
# 221    gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/piControl/r1...             NaN
# 222    gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/piControl/r1...             NaN
# 223    gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/piControl/r1...             NaN
# 496    gs://cmip6/CMIP/BCC/BCC-CSM2-MR/piControl/r1i1...             NaN
# 498    gs://cmip6/CMIP/BCC/BCC-CSM2-MR/piControl/r1i1...             NaN
# ...                                                  ...             ...
# 17166  gs://cmip6/CMIP/SNU/SAM0-UNICON/piControl/r1i1...             NaN
# 17168  gs://cmip6/CMIP/SNU/SAM0-UNICON/piControl/r1i1...             NaN
# 17239  gs://cmip6/CMIP/UA/MCM-UA-1-0/piControl/r1i1p1...             NaN
# 17240  gs://cmip6/CMIP/UA/MCM-UA-1-0/piControl/r1i1p1...             NaN
# 17241  gs://cmip6/CMIP/UA/MCM-UA-1-0/piControl/r1i1p1...             NaN
#
# [66 rows x 10 columns]

# %%
# load to a dictionary of xarray Datasets - may take a minute
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True},
                                cdf_kwargs={'chunks': {'time':20}})
list(dset_dict.keys())
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 24 group(s)
